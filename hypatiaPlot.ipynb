# %%
import numpy as np
import pandas as pd

#Put in your wanted plotting library here
#matplotlib
#import matplotlib.pyplot as plt
#import matplotlib as mpl
#import matplotlob.colors as mc

#seaborn
#import seaborn as sns

#bokeh
#import bokeh as bh
#from bokeh.plotting import figure, show, ColumnDataSource
#from bokeh.io import output_notebook
#from bokeh.transform import linear_cmap, factor_cmap
#from bokeh.util.hex import hexbin

#output_notebook()

#plotly
#import plotly.express as px

# %%
df = pd.read_csv('hypatia-08052022.csv')
print(list(df))
df.head(10)
# Out:
# ['f_preferred_name', 'Fe', 'C', 'O', 'Mg', 'Si', 'S', 'Ca', 'Ti', 'f_ra', 'f_dec', 'f_x', 'f_y', 'f_z', 'f_dist', 'f_disk', 'f_spec', 'f_vmag', 'f_bv', 'f_u', 'f_v', 'f_w', 'f_teff', 'f_logg', 'f_mass', 'f_radius', 'Unnamed: 26']
#           f_preferred_name     Fe      C      O      Mg      Si     S      Ca  \
# 0               HIP 87382   0.060  0.021  0.113  0.0230  0.0210  0.01  0.0890
# 1  2MASS 19290895+4311502   0.080 -0.020  0.190 -0.0400  0.0300   NaN  0.1900
# 2               HIP 98314  -0.345 -0.450 -0.240 -0.1250 -0.2200 -0.10 -0.2400
# 3               HIP 98316  -0.040 -0.070    NaN  0.0165 -0.0130   NaN  0.0300
# 4              HIP 106931  -0.160 -0.080 -0.065 -0.0150 -0.1250  0.16 -0.1400
# 5               HIP 65550  -0.035 -0.265 -0.070 -0.0550  0.0600  0.30  0.0050
# 6               HIP 98329  -0.050 -0.110    NaN -0.0530 -0.0330   NaN  0.0050
# 7               HIP 98333  -0.180 -0.230 -0.190 -0.1500 -0.2300   NaN -0.1000
# 8               HIP 98337  -0.170    NaN    NaN  0.1520  0.1100   NaN -0.2820
# 9               HIP 65574  -0.175 -0.080 -0.010 -0.1585 -0.1495  0.43 -0.1215
#
#       Ti        f_ra  ...  f_vmag   f_bv   f_u   f_v   f_w  f_teff f_logg  \
# 0  0.055  267.808426  ...    6.55  0.541  -0.9   0.7   3.5  6163.0   4.33
# 1  0.070  292.287288  ...     NaN    NaN   NaN   NaN   NaN  6011.9   3.76
# 2 -0.250  299.635904  ...    6.77  0.902  28.6  47.5 -14.9  5002.0   3.13
# 3  0.223  299.637434  ...    8.54  1.050   NaN   NaN   NaN  4739.5   4.33
# 4 -0.080  324.837197  ...    8.06  0.684 -46.2 -16.5  18.2  5575.0   4.46
# 5 -0.045  201.569176  ...    5.88  0.985  20.7   4.4   6.1  4933.0    NaN
# 6  0.078  299.666280  ...    9.38  0.866   NaN   NaN   NaN  5094.0   4.36
# 7 -0.230  299.674374  ...    6.32  0.868 -42.6 -18.3 -11.1  5154.0    NaN
# 8 -0.296  299.689284  ...    3.47  1.571 -35.8 -19.4 -13.7  3944.4   1.25
# 9 -0.020  201.664822  ...    8.78  0.920 -42.2 -26.9  -8.2  4951.5   4.49
#
#    f_mass  f_radius  Unnamed: 26
# 0    1.19      1.29          NaN
# 1    1.11      2.31          NaN
# 2     NaN      5.74          NaN
# 3    0.76      0.75          NaN
# 4    0.98      0.95          NaN
# 5     NaN     10.68          NaN
# 6    0.85      0.81          NaN
# 7     NaN     10.15          NaN
# 8     NaN       NaN          NaN
# 9    0.81      0.74          NaN
#
# [10 rows x 27 columns]

# %%
import matplotlib.pyplot as plt
df2 = df.dropna(subset = ['Fe', 'f_mass', 'f_teff', 'f_radius'])
fig = plt.figure(figsize=(8,8))
ax = fig.add_subplot(111)

sc1 = ax.scatter(df2['f_mass'], df2['f_teff'], c=np.log10(df2['f_radius']), cmap=plt.cm.plasma)
ax.set_xlabel("Mass ($M_{\odot}$)", fontsize=18)
ax.set_ylabel("Effective Temperature (K)", fontsize=18)

cbar = fig.colorbar(sc1)
cbar.set_label(r"$\log$ R ($R_{\odot}$)", fontsize=16)
cbar.ax.tick_params(which='major', axis='both', labelsize=14)

ax.tick_params(which='both', axis='both', labelsize=16)
ax.set_xscale('log')
ax.grid(which='both', axis='both', linestyle=':', alpha=1.0)
plt.show()
